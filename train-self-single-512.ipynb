# %%
import os, shutil, glob, warnings, os
import argparse
import sys
from datetime import datetime

import matplotlib.pyplot as plt
from torchvision import transforms, utils
import torchvision
from skimage import exposure, color, io, img_as_float, img_as_ubyte
from skimage.util import view_as_windows, pad, montage
# from scipy.stats import signaltonoise
from PIL import Image, ImageFilter
import imagej

from math import log10, log, exp, e, log2
import pandas as pd
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from collections import OrderedDict

import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.optim.lr_scheduler as lr_scheduler

import data_self as data
import srmodels as models

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
def data_loader(args, csv='train', dataset_name='TMA'):
    if csv=='train':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv, resolution='512', dataset_name=dataset_name),
                                                   transform=data.Compose([
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers)
    if csv=='valid':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv, resolution='512', dataset_name=dataset_name),
                                                   transform=data.Compose([
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers)
    return dataloader

# %%
def train(args, epoch, run, l, p, dataloader, gan=True):
    epoch_loss = 0
    gan_loss = 0
    total_loss = 0
    dis_loss = 0
    generator.train()
    for iteration, batch in enumerate(dataloader):
        real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
        ### generate 2d dropout
        drop_mask = F.dropout(Variable(torch.ones(real_mid.shape).to(device), requires_grad=False), p=p, inplace=True) # p percent zero, keep
#         drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
#         print(drop_mask)
#         plt.figure(figsize=(20, 10))
#         plt.imshow(utils.make_grid(drop_mask.cpu()).numpy().transpose((1, 2, 0)), interpolation='bicubic')  
#         break
        real_mid = torch.mul(real_mid, drop_mask)
        real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
        
        # Adversarial ground truths
        valid = Variable(Tensor(np.ones((real_mid.size(0), *patch))).to(device), requires_grad=False)
        fake = Variable(Tensor(np.zeros((real_mid.size(0), *patch))).to(device), requires_grad=False)
        
        #---------------
        #  Train Generator
        #---------------   
        
        optimizer_G.zero_grad()
        
        # GAN loss
        fake_high = generator(real_mid)
        if gan:
            pred_fake = discriminator(fake_high, real_mid)
            loss_GAN = criterionMSE(pred_fake, valid)
        
        # Identity
        lossL1 = torch.mean(torch.mul(criterionL(fake_high, real_high), 1/(1-p)-drop_mask)) / p               
        loss_pixel = lossL1
        
        # Total loss
        if gan:
            loss_G = l * loss_GAN + (1-l) * loss_pixel   
            loss_G.backward()
            total_loss = total_loss + loss_G.item()
            gan_loss = gan_loss + loss_GAN.item()
        else:
            loss_pixel.backward()
        optimizer_G.step()
        
        #---------------
        #  Train Discriminator
        #---------------  
        
        if gan and iteration % args.num_critic == 0:
            optimizer_D.zero_grad() 
            # Real loss
            pred_real = discriminator(real_high, real_mid)
            loss_real = criterionMSE(pred_real, valid)
        
            # Fake loss
            pred_fake = discriminator(fake_high.detach(), real_mid)
            loss_fake = criterionMSE(pred_fake, fake)

            # Total loss
            loss_D = 0.5 * (loss_real + loss_fake)
            loss_D.backward()
            optimizer_D.step()
            dis_loss = dis_loss + loss_D.item()
        
        epoch_loss = epoch_loss + loss_pixel.item()
        
        if gan:
            sys.stdout.write('\r[%d/%d][%d/%d] Discriminator_Loss: %.4f Generator_Loss (Identity/Advers/Total): %.4f/%.4f/%.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_D.item(), 
                                loss_pixel.item(), loss_GAN.item(), loss_G.item()))
        else:
            sys.stdout.write('\r[%d/%d][%d/%d] Generator_L1_Loss: %.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_pixel.item()))
    print("\n ===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(dataloader)))
    
    g_path = os.path.join('weights-self', run, 'generator.pth')
    d_path = os.path.join('weights-self', run, 'discriminator.pth')
    os.makedirs(os.path.join('weights-self', run), exist_ok=True)
    torch.save(generator.state_dict(), g_path)
    if gan:
        os.makedirs(os.path.join('weights', run), exist_ok=True)
        torch.save(discriminator.state_dict(), d_path)

# %%
def print_output(trained_model, p, t, dataloader_valid):
    generator.eval()
    os.makedirs('print-512', exist_ok=True)
    with torch.no_grad():      
        print("===> 8x:")
        for iteration, batch in enumerate(dataloader_valid):     
            input, target = batch['input'].to(device), batch['output'].to(device)
            imgs_input = Variable(input.type(Tensor))
            pass_times = int(1/p * t)
            tensor_hyper = torch.zeros((pass_times, imgs_input.shape[0], imgs_input.shape[1], imgs_input.shape[2], imgs_input.shape[3]))
#             print(tensor_hyper.shape)
            for i in range(pass_times):
                drop_mask = F.dropout(Variable(torch.ones(imgs_input.shape).to(device), requires_grad=False), p=p, inplace=True)
#                 drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
                real_mid = torch.mul(imgs_input, drop_mask) 
                prediction = trained_model(real_mid)
                prediction = torch.mul(prediction, 1/(1-p)-drop_mask) / p
                tensor_hyper[i] = prediction.cpu()
            prediction = torch.mean(tensor_hyper, dim=0)
#             prediction = real_mid
#             print(prediction.shape)
            target = target.float()    
            imgs_input = imgs_input[:, :, :, :]
            prediction = prediction[:, :, :, :]
            target = target[:, :, :, :]
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(imgs_input).cpu()
            utils.save_image(grid, 'print-512/input.tif')
            input_downsampled = grid.numpy().transpose((1, 2, 0))
            plt.imshow(input_downsampled, interpolation='bicubic')
            plt.axis('off') 
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(prediction).cpu()
            utils.save_image(grid, 'print-512/output.tif')
            prediction = np.clip(grid.numpy().transpose((1, 2, 0)), 0, 1)
            plt.imshow(prediction, interpolation='bicubic')
            plt.axis('off')    
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(target).cpu()
            utils.save_image(grid, 'print-512/target.tif')
            target = grid.numpy().transpose((1, 2, 0))
            plt.imshow(target, interpolation='bicubic')
            plt.axis('off')                                  
            break

# %%
def p_snr(path_input, path_ref):
    MSE = nn.MSELoss()
    imgs_input = glob.glob(os.path.join(path_input, '*.tiff'))
    imgs_ref = glob.glob(os.path.join(path_ref, '*.tiff'))
    ave_psnr = 0
    for i in range(len(imgs_input)):
        img_input = torch.from_numpy(img_as_float(io.imread(imgs_input[i]).transpose(2, 1, 0)))               
        img_ref = torch.from_numpy(img_as_float(io.imread(imgs_ref[i]).transpose(2, 1, 0)))
        img_input = img_input[None, :]
        img_ref = img_ref[None, :]             
        mse = MSE(img_input, img_ref)               
        psnr = 10 * log10(1 / mse.item())
        ave_psnr += psnr
    ave_psnr = ave_psnr / len(imgs_input)
    return ave_psnr

# %%
def test(args, generator, p, dataloader, criterion):
    with torch.no_grad():
        epoch_loss = 0
        generator.eval()
        for iteration, batch in enumerate(dataloader):
            real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
            drop_mask = F.dropout(Variable(torch.ones(real_mid.shape).to(device), requires_grad=False), p=p, inplace=True)
#             drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
            real_mid = torch.mul(real_mid, drop_mask)
            real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
            fake_high = generator(real_mid)
            loss = torch.mean(torch.mul(criterionL(fake_high, real_high), 1/(1-p)-drop_mask)) / p  
            epoch_loss = epoch_loss + loss.item()
        return epoch_loss / len(dataloader)

# %%
args = argparse.Namespace()
args.img_channel = 1
args.batch_size = 16
args.patch_size = 512
args.up_scale = 5
args.num_workers = 0
args.num_epochs = 200
args.g_lr = 0.0001
args.d_lr = 0.00001
args.dataset = 'TMA'
args.num_critic = 10
args.normalize = None
args.percep_weight = 0.02
args.dropout_rate = 0.1
args.average_factor = 100
args.run_from = 'self-slice-512-0.005-2021-04-18--17-07-11'
args.start_epoch = 1
args.gan = True

# %%
device = torch.device('cuda:0')
data.generate_compress_csv(resolution='512', dataset_name="TMA-slice")
valid_dataset = data_loader(args, 'valid', dataset_name="TMA-slice")
data.show_patch(valid_dataset, 0)
# define model
generator = models.Generator(args.img_channel, base_channel=16, norm='instance')
# generator = models.Net(args.img_channel, upscale_factor=2)
generator.to(device);
discriminator = models.Discriminator(args.img_channel, norm='batch')
discriminator.to(device);
criterionL = nn.MSELoss(reduction='none').cuda() # nn.L1Loss(reduction='none').cuda()
criterionMSE = nn.MSELoss(reduction='none').cuda()
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
patch = (1, args.patch_size // 2 ** 4, args.patch_size // 2 ** 4)
Tensor = torch.cuda.FloatTensor

# %%
if args.run_from is not None:
    generator.load_state_dict(torch.load(os.path.join('weights-self', args.run_from, 'generator.pth')))
    try:
        discriminator.load_state_dict(torch.load(os.path.join('weights-self', args.run_from, 'discriminator.pth')))
    except:
        print('Discriminator weights not found!')
        pass
# Out:
# Discriminator weights not found!

# %%
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
scheduler_G = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_G, args.num_epochs, args.g_lr*0.05)
scheduler_D = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_D, args.num_epochs, args.d_lr*0.05)

# %%
warnings.filterwarnings('ignore')

# %%
run = 'self-slice-512-gamma-0.1' + '-' + datetime.now().strftime("%Y-%m-%d--%H-%M-%S")
train_dataset = data_loader(args, 'train', "TMA-slice")
l = args.percep_weight
p = args.dropout_rate 
for epoch in range(0, 100):
    gan = False
    train(args, epoch, run, l, p, train_dataset, gan)   
    scheduler_G.step()
    scheduler_D.step()
    if epoch % 10 == 0:
        test_loss = test(args, generator, p, valid_dataset, criterion=criterionMSE)
        print('\r>>>> [{}/{}] test_loss: {}'.format(epoch, args.num_epochs, test_loss))
# Out:
# [0/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 0 Complete: Avg. Loss: 0.0059
# >>>> [0/200] test_loss: 0.005883520975818529
# [1/200][1631/1632] Generator_L1_Loss: 0.0060
#  ===> Epoch 1 Complete: Avg. Loss: 0.0059
# [2/200][1631/1632] Generator_L1_Loss: 0.0057
#  ===> Epoch 2 Complete: Avg. Loss: 0.0058
# [3/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 3 Complete: Avg. Loss: 0.0058
# [4/200][1631/1632] Generator_L1_Loss: 0.0060
#  ===> Epoch 4 Complete: Avg. Loss: 0.0058
# [5/200][1631/1632] Generator_L1_Loss: 0.0051
#  ===> Epoch 5 Complete: Avg. Loss: 0.0058
# [6/200][1631/1632] Generator_L1_Loss: 0.0064
#  ===> Epoch 6 Complete: Avg. Loss: 0.0058
# [7/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 7 Complete: Avg. Loss: 0.0058
# [8/200][1631/1632] Generator_L1_Loss: 0.0050
#  ===> Epoch 8 Complete: Avg. Loss: 0.0058
# [9/200][1631/1632] Generator_L1_Loss: 0.0049
#  ===> Epoch 9 Complete: Avg. Loss: 0.0058
# [10/200][1631/1632] Generator_L1_Loss: 0.0084
#  ===> Epoch 10 Complete: Avg. Loss: 0.0058
# >>>> [10/200] test_loss: 0.005813242221598094
# [11/200][1631/1632] Generator_L1_Loss: 0.0059
#  ===> Epoch 11 Complete: Avg. Loss: 0.0058
# [12/200][1631/1632] Generator_L1_Loss: 0.0052
#  ===> Epoch 12 Complete: Avg. Loss: 0.0058
# [13/200][1631/1632] Generator_L1_Loss: 0.0063
#  ===> Epoch 13 Complete: Avg. Loss: 0.0058
# [14/200][1631/1632] Generator_L1_Loss: 0.0040
#  ===> Epoch 14 Complete: Avg. Loss: 0.0058
# [15/200][1631/1632] Generator_L1_Loss: 0.0066
#  ===> Epoch 15 Complete: Avg. Loss: 0.0058
# [16/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 16 Complete: Avg. Loss: 0.0058
# [17/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 17 Complete: Avg. Loss: 0.0058
# [18/200][1631/1632] Generator_L1_Loss: 0.0068
#  ===> Epoch 18 Complete: Avg. Loss: 0.0058
# [19/200][1631/1632] Generator_L1_Loss: 0.0068
#  ===> Epoch 19 Complete: Avg. Loss: 0.0058
# [20/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 20 Complete: Avg. Loss: 0.0058
# >>>> [20/200] test_loss: 0.005793407868694368
# [21/200][1631/1632] Generator_L1_Loss: 0.0048
#  ===> Epoch 21 Complete: Avg. Loss: 0.0058
# [22/200][1631/1632] Generator_L1_Loss: 0.0046
#  ===> Epoch 22 Complete: Avg. Loss: 0.0058
# [23/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 23 Complete: Avg. Loss: 0.0058
# [24/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 24 Complete: Avg. Loss: 0.0058
# [25/200][1631/1632] Generator_L1_Loss: 0.0056
#  ===> Epoch 25 Complete: Avg. Loss: 0.0058
# [26/200][1631/1632] Generator_L1_Loss: 0.0066
#  ===> Epoch 26 Complete: Avg. Loss: 0.0058
# [27/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 27 Complete: Avg. Loss: 0.0058
# [28/200][1631/1632] Generator_L1_Loss: 0.0048
#  ===> Epoch 28 Complete: Avg. Loss: 0.0058
# [29/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 29 Complete: Avg. Loss: 0.0058
# [30/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 30 Complete: Avg. Loss: 0.0058
# >>>> [30/200] test_loss: 0.005776258133004839
# [31/200][1631/1632] Generator_L1_Loss: 0.0071
#  ===> Epoch 31 Complete: Avg. Loss: 0.0058
# [32/200][1631/1632] Generator_L1_Loss: 0.0050
#  ===> Epoch 32 Complete: Avg. Loss: 0.0058
# [33/200][1631/1632] Generator_L1_Loss: 0.0046
#  ===> Epoch 33 Complete: Avg. Loss: 0.0058
# [34/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 34 Complete: Avg. Loss: 0.0058
# [35/200][1631/1632] Generator_L1_Loss: 0.0058
#  ===> Epoch 35 Complete: Avg. Loss: 0.0058
# [36/200][1631/1632] Generator_L1_Loss: 0.0047
#  ===> Epoch 36 Complete: Avg. Loss: 0.0058
# [37/200][1631/1632] Generator_L1_Loss: 0.0045
#  ===> Epoch 37 Complete: Avg. Loss: 0.0057
# [38/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 38 Complete: Avg. Loss: 0.0058
# [39/200][1631/1632] Generator_L1_Loss: 0.0067
#  ===> Epoch 39 Complete: Avg. Loss: 0.0057
# [40/200][1631/1632] Generator_L1_Loss: 0.0063
#  ===> Epoch 40 Complete: Avg. Loss: 0.0057
# >>>> [40/200] test_loss: 0.0057648700061619425
# [41/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 41 Complete: Avg. Loss: 0.0057
# [42/200][1631/1632] Generator_L1_Loss: 0.0043
#  ===> Epoch 42 Complete: Avg. Loss: 0.0057
# [43/200][1631/1632] Generator_L1_Loss: 0.0045
#  ===> Epoch 43 Complete: Avg. Loss: 0.0057
# [44/200][1631/1632] Generator_L1_Loss: 0.0052
#  ===> Epoch 44 Complete: Avg. Loss: 0.0057
# [45/200][1631/1632] Generator_L1_Loss: 0.0058
#  ===> Epoch 45 Complete: Avg. Loss: 0.0057
# [46/200][1631/1632] Generator_L1_Loss: 0.0056
#  ===> Epoch 46 Complete: Avg. Loss: 0.0057
# [47/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 47 Complete: Avg. Loss: 0.0057
# [48/200][1631/1632] Generator_L1_Loss: 0.0050
#  ===> Epoch 48 Complete: Avg. Loss: 0.0057
# [49/200][1631/1632] Generator_L1_Loss: 0.0051
#  ===> Epoch 49 Complete: Avg. Loss: 0.0057
# [50/200][1631/1632] Generator_L1_Loss: 0.0049
#  ===> Epoch 50 Complete: Avg. Loss: 0.0057
# >>>> [50/200] test_loss: 0.005757983625574293
# [51/200][1631/1632] Generator_L1_Loss: 0.0062
#  ===> Epoch 51 Complete: Avg. Loss: 0.0057
# [52/200][1631/1632] Generator_L1_Loss: 0.0064
#  ===> Epoch 52 Complete: Avg. Loss: 0.0057
# [53/200][1631/1632] Generator_L1_Loss: 0.0052
#  ===> Epoch 53 Complete: Avg. Loss: 0.0057
# [54/200][1631/1632] Generator_L1_Loss: 0.0051
#  ===> Epoch 54 Complete: Avg. Loss: 0.0057
# [55/200][1631/1632] Generator_L1_Loss: 0.0062
#  ===> Epoch 55 Complete: Avg. Loss: 0.0057
# [56/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 56 Complete: Avg. Loss: 0.0057
# [57/200][1631/1632] Generator_L1_Loss: 0.0057
#  ===> Epoch 57 Complete: Avg. Loss: 0.0057
# [58/200][1631/1632] Generator_L1_Loss: 0.0064
#  ===> Epoch 58 Complete: Avg. Loss: 0.0057
# [59/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 59 Complete: Avg. Loss: 0.0057
# [60/200][1631/1632] Generator_L1_Loss: 0.0050
#  ===> Epoch 60 Complete: Avg. Loss: 0.0057
# >>>> [60/200] test_loss: 0.005753827883916742
# [61/200][1631/1632] Generator_L1_Loss: 0.0069
#  ===> Epoch 61 Complete: Avg. Loss: 0.0057
# [62/200][1631/1632] Generator_L1_Loss: 0.0063
#  ===> Epoch 62 Complete: Avg. Loss: 0.0057
# [63/200][1631/1632] Generator_L1_Loss: 0.0067
#  ===> Epoch 63 Complete: Avg. Loss: 0.0057
# [64/200][1631/1632] Generator_L1_Loss: 0.0058
#  ===> Epoch 64 Complete: Avg. Loss: 0.0057
# [65/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 65 Complete: Avg. Loss: 0.0057
# [66/200][1631/1632] Generator_L1_Loss: 0.0056
#  ===> Epoch 66 Complete: Avg. Loss: 0.0057
# [67/200][1631/1632] Generator_L1_Loss: 0.0061
#  ===> Epoch 67 Complete: Avg. Loss: 0.0057
# [68/200][1631/1632] Generator_L1_Loss: 0.0046
#  ===> Epoch 68 Complete: Avg. Loss: 0.0057
# [69/200][1631/1632] Generator_L1_Loss: 0.0076
#  ===> Epoch 69 Complete: Avg. Loss: 0.0057
# [70/200][1631/1632] Generator_L1_Loss: 0.0057
#  ===> Epoch 70 Complete: Avg. Loss: 0.0057
# >>>> [70/200] test_loss: 0.005748632581968445
# [71/200][1631/1632] Generator_L1_Loss: 0.0064
#  ===> Epoch 71 Complete: Avg. Loss: 0.0057
# [72/200][1631/1632] Generator_L1_Loss: 0.0059
#  ===> Epoch 72 Complete: Avg. Loss: 0.0057
# [73/200][1631/1632] Generator_L1_Loss: 0.0048
#  ===> Epoch 73 Complete: Avg. Loss: 0.0057
# [74/200][1631/1632] Generator_L1_Loss: 0.0061
#  ===> Epoch 74 Complete: Avg. Loss: 0.0057
# [75/200][1631/1632] Generator_L1_Loss: 0.0057
#  ===> Epoch 75 Complete: Avg. Loss: 0.0057
# [76/200][1631/1632] Generator_L1_Loss: 0.0078
#  ===> Epoch 76 Complete: Avg. Loss: 0.0057
# [77/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 77 Complete: Avg. Loss: 0.0057
# [78/200][1631/1632] Generator_L1_Loss: 0.0061
#  ===> Epoch 78 Complete: Avg. Loss: 0.0057
# [79/200][1631/1632] Generator_L1_Loss: 0.0065
#  ===> Epoch 79 Complete: Avg. Loss: 0.0057
# [80/200][1631/1632] Generator_L1_Loss: 0.0045
#  ===> Epoch 80 Complete: Avg. Loss: 0.0057
# >>>> [80/200] test_loss: 0.005744613021128245
# [81/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 81 Complete: Avg. Loss: 0.0057
# [82/200][1631/1632] Generator_L1_Loss: 0.0049
#  ===> Epoch 82 Complete: Avg. Loss: 0.0057
# [83/200][1631/1632] Generator_L1_Loss: 0.0059
#  ===> Epoch 83 Complete: Avg. Loss: 0.0057
# [84/200][1631/1632] Generator_L1_Loss: 0.0064
#  ===> Epoch 84 Complete: Avg. Loss: 0.0057
# [85/200][1631/1632] Generator_L1_Loss: 0.0063
#  ===> Epoch 85 Complete: Avg. Loss: 0.0057
# [86/200][1631/1632] Generator_L1_Loss: 0.0061
#  ===> Epoch 86 Complete: Avg. Loss: 0.0057
# [87/200][1631/1632] Generator_L1_Loss: 0.0058
#  ===> Epoch 87 Complete: Avg. Loss: 0.0057
# [88/200][1631/1632] Generator_L1_Loss: 0.0066
#  ===> Epoch 88 Complete: Avg. Loss: 0.0057
# [89/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 89 Complete: Avg. Loss: 0.0057
# [90/200][1631/1632] Generator_L1_Loss: 0.0052
#  ===> Epoch 90 Complete: Avg. Loss: 0.0057
# >>>> [90/200] test_loss: 0.005739766109150415
# [91/200][1631/1632] Generator_L1_Loss: 0.0076
#  ===> Epoch 91 Complete: Avg. Loss: 0.0057
# [92/200][1631/1632] Generator_L1_Loss: 0.0055
#  ===> Epoch 92 Complete: Avg. Loss: 0.0057
# [93/200][1631/1632] Generator_L1_Loss: 0.0070
#  ===> Epoch 93 Complete: Avg. Loss: 0.0057
# [94/200][1631/1632] Generator_L1_Loss: 0.0045
#  ===> Epoch 94 Complete: Avg. Loss: 0.0057
# [95/200][1631/1632] Generator_L1_Loss: 0.0062
#  ===> Epoch 95 Complete: Avg. Loss: 0.0057
# [96/200][1631/1632] Generator_L1_Loss: 0.0058
#  ===> Epoch 96 Complete: Avg. Loss: 0.0057
# [97/200][1631/1632] Generator_L1_Loss: 0.0054
#  ===> Epoch 97 Complete: Avg. Loss: 0.0057
# [98/200][1631/1632] Generator_L1_Loss: 0.0048
#  ===> Epoch 98 Complete: Avg. Loss: 0.0057
# [99/200][1631/1632] Generator_L1_Loss: 0.0053
#  ===> Epoch 99 Complete: Avg. Loss: 0.0057

# %%
valid_dataset = data_loader(args, 'valid')
test_loss = test(args, generator, p, valid_dataset, criterion=criterionMSE)

# %%
test_loss
# Out:
# 0.004491226463970535

# %%
t = 50
l = args.percep_weight
p = args.dropout_rate 
print_output(generator, p, t, train_dataset)
# Out:
# ===> 8x:

# %%
t = 100
l = args.percep_weight
p = args.dropout_rate 
print_output(generator, p, t, train_dataset)
# Out:
# ===> 8x:
