# %%
import os, shutil, glob, warnings, os
import argparse
import sys
from datetime import datetime

import matplotlib.pyplot as plt
from torchvision import transforms, utils
import torchvision
from skimage import exposure, color, io, img_as_float, img_as_ubyte
from skimage.util import view_as_windows, pad, montage
# from scipy.stats import signaltonoise
from PIL import Image, ImageFilter
import imagej

from math import log10, log, exp, e, log2
import pandas as pd
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from collections import OrderedDict

import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.optim.lr_scheduler as lr_scheduler

import data_self as data
import srmodels as models

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
def data_loader(args, csv='train'):
    if csv=='train':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv, resolution='512'),
                                                   transform=data.Compose([
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers)
    if csv=='valid':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv, resolution='512'),
                                                   transform=data.Compose([
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers)
    return dataloader

# %%
def train(args, epoch, run, l, p, dataloader, gan=True):
    epoch_loss = 0
    gan_loss = 0
    total_loss = 0
    dis_loss = 0
    generator.train()
    for iteration, batch in enumerate(dataloader):
        real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
        ### generate 2d dropout
        drop_mask = F.dropout(Variable(torch.ones(real_mid.shape).to(device), requires_grad=False), p=p, inplace=True) # p percent zero, keep
#         drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
#         print(drop_mask)
#         plt.figure(figsize=(20, 10))
#         plt.imshow(utils.make_grid(drop_mask.cpu()).numpy().transpose((1, 2, 0)), interpolation='bicubic')  
#         break
        real_mid = torch.mul(real_mid, drop_mask)
        real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
        
        # Adversarial ground truths
        valid = Variable(Tensor(np.ones((real_mid.size(0), *patch))).to(device), requires_grad=False)
        fake = Variable(Tensor(np.zeros((real_mid.size(0), *patch))).to(device), requires_grad=False)
        
        #---------------
        #  Train Generator
        #---------------   
        
        optimizer_G.zero_grad()
        
        # GAN loss
        fake_high = generator(real_mid)
        if gan:
            pred_fake = discriminator(fake_high, real_mid)
            loss_GAN = criterionMSE(pred_fake, valid)
        
        # Identity
        lossL1 = torch.mean(torch.mul(criterionL(fake_high, real_high), 1/(1-p)-drop_mask)) / p               
        loss_pixel = lossL1
        
        # Total loss
        if gan:
            loss_G = l * loss_GAN + (1-l) * loss_pixel   
            loss_G.backward()
            total_loss = total_loss + loss_G.item()
            gan_loss = gan_loss + loss_GAN.item()
        else:
            loss_pixel.backward()
        optimizer_G.step()
        
        #---------------
        #  Train Discriminator
        #---------------  
        
        if gan and iteration % args.num_critic == 0:
            optimizer_D.zero_grad() 
            # Real loss
            pred_real = discriminator(real_high, real_mid)
            loss_real = criterionMSE(pred_real, valid)
        
            # Fake loss
            pred_fake = discriminator(fake_high.detach(), real_mid)
            loss_fake = criterionMSE(pred_fake, fake)

            # Total loss
            loss_D = 0.5 * (loss_real + loss_fake)
            loss_D.backward()
            optimizer_D.step()
            dis_loss = dis_loss + loss_D.item()
        
        epoch_loss = epoch_loss + loss_pixel.item()
        
        if gan:
            sys.stdout.write('\r[%d/%d][%d/%d] Discriminator_Loss: %.4f Generator_Loss (Identity/Advers/Total): %.4f/%.4f/%.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_D.item(), 
                                loss_pixel.item(), loss_GAN.item(), loss_G.item()))
        else:
            sys.stdout.write('\r[%d/%d][%d/%d] Generator_L1_Loss: %.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_pixel.item()))
    print("\n ===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(dataloader)))
    
    g_path = os.path.join('weights-self', run, 'generator.pth')
    d_path = os.path.join('weights-self', run, 'discriminator.pth')
    os.makedirs(os.path.join('weights-self', run), exist_ok=True)
    torch.save(generator.state_dict(), g_path)
    if gan:
        os.makedirs(os.path.join('weights', run), exist_ok=True)
        torch.save(discriminator.state_dict(), d_path)

# %%
def print_output(trained_model, p, t, dataloader_valid):
    generator.eval()
    os.makedirs('print-512', exist_ok=True)
    with torch.no_grad():      
        print("===> 8x:")
        for iteration, batch in enumerate(dataloader_valid):     
            input, target = batch['input'].to(device), batch['output'].to(device)
            imgs_input = Variable(input.type(Tensor))
            pass_times = int(1/p * t)
            tensor_hyper = torch.zeros((pass_times, imgs_input.shape[0], imgs_input.shape[1], imgs_input.shape[2], imgs_input.shape[3]))
#             print(tensor_hyper.shape)
            for i in range(pass_times):
                drop_mask = F.dropout(Variable(torch.ones(imgs_input.shape).to(device), requires_grad=False), p=p, inplace=True)
#                 drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
                real_mid = torch.mul(imgs_input, drop_mask) 
                prediction = trained_model(real_mid)
                prediction = torch.mul(prediction, 1/(1-p)-drop_mask) / p
                tensor_hyper[i] = prediction.cpu()
            prediction = torch.mean(tensor_hyper, dim=0)
#             prediction = real_mid
#             print(prediction.shape)
            target = target.float()    
            imgs_input = imgs_input[:, :, :, :]
            prediction = prediction[:, :, :, :]
            target = target[:, :, :, :]
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(imgs_input).cpu()
            utils.save_image(grid, 'print-512/input.tif')
            input_downsampled = grid.numpy().transpose((1, 2, 0))
            plt.imshow(input_downsampled, interpolation='bicubic')
            plt.axis('off') 
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(prediction).cpu()
            utils.save_image(grid, 'print-512/output.tif')
            prediction = np.clip(grid.numpy().transpose((1, 2, 0)), 0, 1)
            plt.imshow(prediction, interpolation='bicubic')
            plt.axis('off')    
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(target).cpu()
            utils.save_image(grid, 'print-512/target.tif')
            target = grid.numpy().transpose((1, 2, 0))
            plt.imshow(target, interpolation='bicubic')
            plt.axis('off')                                  
            break

# %%
def p_snr(path_input, path_ref):
    MSE = nn.MSELoss()
    imgs_input = glob.glob(os.path.join(path_input, '*.tiff'))
    imgs_ref = glob.glob(os.path.join(path_ref, '*.tiff'))
    ave_psnr = 0
    for i in range(len(imgs_input)):
        img_input = torch.from_numpy(img_as_float(io.imread(imgs_input[i]).transpose(2, 1, 0)))               
        img_ref = torch.from_numpy(img_as_float(io.imread(imgs_ref[i]).transpose(2, 1, 0)))
        img_input = img_input[None, :]
        img_ref = img_ref[None, :]             
        mse = MSE(img_input, img_ref)               
        psnr = 10 * log10(1 / mse.item())
        ave_psnr += psnr
    ave_psnr = ave_psnr / len(imgs_input)
    return ave_psnr

# %%
def test(args, generator, p, dataloader, criterion):
    with torch.no_grad():
        epoch_loss = 0
        generator.eval()
        for iteration, batch in enumerate(dataloader):
            real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
            drop_mask = F.dropout(Variable(torch.ones(real_mid.shape).to(device), requires_grad=False), p=p, inplace=True)
#             drop_mask = F.interpolate(drop_mask[:, :, 192:320, 192:320], scale_factor=4, mode='nearest')
            real_mid = torch.mul(real_mid, drop_mask)
            real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
            fake_high = generator(real_mid)
            loss = torch.mean(torch.mul(criterionL(fake_high, real_high), 1/(1-p)-drop_mask)) / p  
            epoch_loss = epoch_loss + loss.item()
        return epoch_loss / len(dataloader)

# %%
args = argparse.Namespace()
args.img_channel = 1
args.batch_size = 16
args.patch_size = 512
args.up_scale = 5
args.num_workers = 0
args.num_epochs = 200
args.g_lr = 0.0001
args.d_lr = 0.00001
args.dataset = 'TMA'
args.num_critic = 10
args.normalize = None
args.percep_weight = 0.02
args.dropout_rate = 0.05
args.average_factor = 100
args.run_from = None
args.start_epoch = 1
args.gan = True

# %%
device = torch.device('cuda:0')
data.generate_compress_csv(resolution='512')
valid_dataset = data_loader(args, 'valid')
data.show_patch(valid_dataset, 0)
# define model
generator = models.Generator(args.img_channel, base_channel=16, norm='instance')
# generator = models.Net(args.img_channel, upscale_factor=2)
generator.to(device);
discriminator = models.Discriminator(args.img_channel, norm='batch')
discriminator.to(device);
criterionL = nn.L1Loss(reduction='none').cuda()
criterionMSE = nn.MSELoss(reduction='none').cuda()
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
patch = (1, args.patch_size // 2 ** 4, args.patch_size // 2 ** 4)
Tensor = torch.cuda.FloatTensor

# %%
if args.run_from is not None:
    generator.load_state_dict(torch.load(os.path.join('weights-self', args.run_from, 'generator.pth')))
    try:
        discriminator.load_state_dict(torch.load(os.path.join('weights-self', args.run_from, 'discriminator.pth')))
    except:
        print('Discriminator weights not found!')
        pass

# %%
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
scheduler_G = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_G, args.num_epochs, args.g_lr*0.05)
scheduler_D = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_D, args.num_epochs, args.d_lr*0.05)

# %%
warnings.filterwarnings('ignore')

# %%
run = 'self-512-0.05' + '-' + datetime.now().strftime("%Y-%m-%d--%H-%M-%S")
train_dataset = data_loader(args, 'train')
l = args.percep_weight
p = args.dropout_rate 
for epoch in range(0, args.num_epochs):
    gan = False
    train(args, epoch, run, l, p, train_dataset, gan)   
    scheduler_G.step()
    scheduler_D.step()
    if epoch % 10 == 0:
        test_loss = test(args, generator, p, valid_dataset, criterion=criterionMSE)
        print('\r>>>> [{}/{}] test_loss: {}'.format(epoch, args.num_epochs, test_loss))
# Out:
# [0/200][3161/3162] Generator_L1_Loss: 0.0895
#  ===> Epoch 0 Complete: Avg. Loss: 0.0807
# >>>> [0/200] test_loss: 0.07910368873180842
# [1/200][3161/3162] Generator_L1_Loss: 0.0781
#  ===> Epoch 1 Complete: Avg. Loss: 0.0790
# [2/200][3161/3162] Generator_L1_Loss: 0.0826
#  ===> Epoch 2 Complete: Avg. Loss: 0.0788
# [3/200][3161/3162] Generator_L1_Loss: 0.0815
#  ===> Epoch 3 Complete: Avg. Loss: 0.0786
# [4/200][3161/3162] Generator_L1_Loss: 0.0804
#  ===> Epoch 4 Complete: Avg. Loss: 0.0785
# [5/200][3161/3162] Generator_L1_Loss: 0.0741
#  ===> Epoch 5 Complete: Avg. Loss: 0.0784
# [6/200][3161/3162] Generator_L1_Loss: 0.0743
#  ===> Epoch 6 Complete: Avg. Loss: 0.0784
# [7/200][3161/3162] Generator_L1_Loss: 0.0772
#  ===> Epoch 7 Complete: Avg. Loss: 0.0783
# [8/200][3161/3162] Generator_L1_Loss: 0.0751
#  ===> Epoch 8 Complete: Avg. Loss: 0.0782
# [9/200][3161/3162] Generator_L1_Loss: 0.0836
#  ===> Epoch 9 Complete: Avg. Loss: 0.0781
# [10/200][3161/3162] Generator_L1_Loss: 0.0794
#  ===> Epoch 10 Complete: Avg. Loss: 0.0780
# >>>> [10/200] test_loss: 0.07788185249689104
# [11/200][3161/3162] Generator_L1_Loss: 0.0716
#  ===> Epoch 11 Complete: Avg. Loss: 0.0780
# [12/200][3161/3162] Generator_L1_Loss: 0.0736
#  ===> Epoch 12 Complete: Avg. Loss: 0.0779
# [13/200][3161/3162] Generator_L1_Loss: 0.0701
#  ===> Epoch 13 Complete: Avg. Loss: 0.0779
# [14/200][3161/3162] Generator_L1_Loss: 0.0745
#  ===> Epoch 14 Complete: Avg. Loss: 0.0778
# [15/200][3161/3162] Generator_L1_Loss: 0.0709
#  ===> Epoch 15 Complete: Avg. Loss: 0.0778
# [16/200][3161/3162] Generator_L1_Loss: 0.0764
#  ===> Epoch 16 Complete: Avg. Loss: 0.0778
# [17/200][3161/3162] Generator_L1_Loss: 0.0825
#  ===> Epoch 17 Complete: Avg. Loss: 0.0777
# [18/200][3161/3162] Generator_L1_Loss: 0.0735
#  ===> Epoch 18 Complete: Avg. Loss: 0.0777
# [19/200][3161/3162] Generator_L1_Loss: 0.0780
#  ===> Epoch 19 Complete: Avg. Loss: 0.0777
# [20/200][3161/3162] Generator_L1_Loss: 0.0796
#  ===> Epoch 20 Complete: Avg. Loss: 0.0776
# >>>> [20/200] test_loss: 0.07745660854651865
# [21/200][3161/3162] Generator_L1_Loss: 0.0760
#  ===> Epoch 21 Complete: Avg. Loss: 0.0776
# [22/200][3161/3162] Generator_L1_Loss: 0.0773
#  ===> Epoch 22 Complete: Avg. Loss: 0.0776
# [23/200][3161/3162] Generator_L1_Loss: 0.0744
#  ===> Epoch 23 Complete: Avg. Loss: 0.0775
# [24/200][3161/3162] Generator_L1_Loss: 0.0827
#  ===> Epoch 24 Complete: Avg. Loss: 0.0774
# [25/200][3161/3162] Generator_L1_Loss: 0.0787
#  ===> Epoch 25 Complete: Avg. Loss: 0.0773
# [26/200][3161/3162] Generator_L1_Loss: 0.0746
#  ===> Epoch 26 Complete: Avg. Loss: 0.0772
# [27/200][3161/3162] Generator_L1_Loss: 0.0796
#  ===> Epoch 27 Complete: Avg. Loss: 0.0771
# [28/200][3161/3162] Generator_L1_Loss: 0.0712
#  ===> Epoch 28 Complete: Avg. Loss: 0.0771
# [29/200][3161/3162] Generator_L1_Loss: 0.0780
#  ===> Epoch 29 Complete: Avg. Loss: 0.0770
# [30/200][3161/3162] Generator_L1_Loss: 0.0807
#  ===> Epoch 30 Complete: Avg. Loss: 0.0770
# >>>> [30/200] test_loss: 0.07685857415952815
# [31/200][3161/3162] Generator_L1_Loss: 0.0745
#  ===> Epoch 31 Complete: Avg. Loss: 0.0770
# [32/200][3161/3162] Generator_L1_Loss: 0.0759
#  ===> Epoch 32 Complete: Avg. Loss: 0.0769
# [33/200][3161/3162] Generator_L1_Loss: 0.0780
#  ===> Epoch 33 Complete: Avg. Loss: 0.0769
# [34/200][3161/3162] Generator_L1_Loss: 0.0709
#  ===> Epoch 34 Complete: Avg. Loss: 0.0769
# [35/200][3161/3162] Generator_L1_Loss: 0.0750
#  ===> Epoch 35 Complete: Avg. Loss: 0.0769
# [36/200][3161/3162] Generator_L1_Loss: 0.0728
#  ===> Epoch 36 Complete: Avg. Loss: 0.0768
# [37/200][3161/3162] Generator_L1_Loss: 0.0747
#  ===> Epoch 37 Complete: Avg. Loss: 0.0768
# [38/200][3161/3162] Generator_L1_Loss: 0.0812
#  ===> Epoch 38 Complete: Avg. Loss: 0.0768
# [39/200][3161/3162] Generator_L1_Loss: 0.0768
#  ===> Epoch 39 Complete: Avg. Loss: 0.0768
# [40/200][3161/3162] Generator_L1_Loss: 0.0756
#  ===> Epoch 40 Complete: Avg. Loss: 0.0767
# >>>> [40/200] test_loss: 0.07668854737025597
# [41/200][3161/3162] Generator_L1_Loss: 0.0704
#  ===> Epoch 41 Complete: Avg. Loss: 0.0767
# [42/200][3161/3162] Generator_L1_Loss: 0.0778
#  ===> Epoch 42 Complete: Avg. Loss: 0.0767
# [43/200][3161/3162] Generator_L1_Loss: 0.0793
#  ===> Epoch 43 Complete: Avg. Loss: 0.0767
# [44/200][3161/3162] Generator_L1_Loss: 0.0796
#  ===> Epoch 44 Complete: Avg. Loss: 0.0767
# [45/200][3161/3162] Generator_L1_Loss: 0.0745
#  ===> Epoch 45 Complete: Avg. Loss: 0.0766
# [46/200][3161/3162] Generator_L1_Loss: 0.0807
#  ===> Epoch 46 Complete: Avg. Loss: 0.0766
# [47/200][3161/3162] Generator_L1_Loss: 0.0721
#  ===> Epoch 47 Complete: Avg. Loss: 0.0766
# [48/200][3161/3162] Generator_L1_Loss: 0.0700
#  ===> Epoch 48 Complete: Avg. Loss: 0.0766
# [49/200][3161/3162] Generator_L1_Loss: 0.0760
#  ===> Epoch 49 Complete: Avg. Loss: 0.0766
# [50/200][3161/3162] Generator_L1_Loss: 0.0786
#  ===> Epoch 50 Complete: Avg. Loss: 0.0766
# >>>> [50/200] test_loss: 0.07645250823909203
# [51/200][3161/3162] Generator_L1_Loss: 0.0795
#  ===> Epoch 51 Complete: Avg. Loss: 0.0765
# [52/200][3161/3162] Generator_L1_Loss: 0.0724
#  ===> Epoch 52 Complete: Avg. Loss: 0.0765
# [53/200][3161/3162] Generator_L1_Loss: 0.0776
#  ===> Epoch 53 Complete: Avg. Loss: 0.0765
# [54/200][3161/3162] Generator_L1_Loss: 0.0842
#  ===> Epoch 54 Complete: Avg. Loss: 0.0765
# [55/200][3161/3162] Generator_L1_Loss: 0.0865
#  ===> Epoch 55 Complete: Avg. Loss: 0.0765
# [56/200][3161/3162] Generator_L1_Loss: 0.0674
#  ===> Epoch 56 Complete: Avg. Loss: 0.0765
# [57/200][3161/3162] Generator_L1_Loss: 0.0743
#  ===> Epoch 57 Complete: Avg. Loss: 0.0764
# [58/200][3161/3162] Generator_L1_Loss: 0.0769
#  ===> Epoch 58 Complete: Avg. Loss: 0.0764
# [59/200][3161/3162] Generator_L1_Loss: 0.0758
#  ===> Epoch 59 Complete: Avg. Loss: 0.0764
# [60/200][3161/3162] Generator_L1_Loss: 0.0669
#  ===> Epoch 60 Complete: Avg. Loss: 0.0764
# >>>> [60/200] test_loss: 0.0762974460304311
# [61/200][3161/3162] Generator_L1_Loss: 0.0713
#  ===> Epoch 61 Complete: Avg. Loss: 0.0764
# [62/200][3161/3162] Generator_L1_Loss: 0.0789
#  ===> Epoch 62 Complete: Avg. Loss: 0.0763
# [63/200][3161/3162] Generator_L1_Loss: 0.0822
#  ===> Epoch 63 Complete: Avg. Loss: 0.0763
# [64/200][3161/3162] Generator_L1_Loss: 0.0768
#  ===> Epoch 64 Complete: Avg. Loss: 0.0763
# [65/200][3161/3162] Generator_L1_Loss: 0.0803
#  ===> Epoch 65 Complete: Avg. Loss: 0.0763
# [66/200][3161/3162] Generator_L1_Loss: 0.0757
#  ===> Epoch 66 Complete: Avg. Loss: 0.0763
# [67/200][3161/3162] Generator_L1_Loss: 0.0722
#  ===> Epoch 67 Complete: Avg. Loss: 0.0763
# [68/200][3161/3162] Generator_L1_Loss: 0.0763
#  ===> Epoch 68 Complete: Avg. Loss: 0.0763
# [69/200][3161/3162] Generator_L1_Loss: 0.0745
#  ===> Epoch 69 Complete: Avg. Loss: 0.0762
# [70/200][3161/3162] Generator_L1_Loss: 0.0705
#  ===> Epoch 70 Complete: Avg. Loss: 0.0762
# >>>> [70/200] test_loss: 0.07608236776554178
# [71/200][3161/3162] Generator_L1_Loss: 0.0766
#  ===> Epoch 71 Complete: Avg. Loss: 0.0762
# [72/200][3161/3162] Generator_L1_Loss: 0.0759
#  ===> Epoch 72 Complete: Avg. Loss: 0.0762
# [73/200][3161/3162] Generator_L1_Loss: 0.0749
#  ===> Epoch 73 Complete: Avg. Loss: 0.0762
# [74/200][3161/3162] Generator_L1_Loss: 0.0718
#  ===> Epoch 74 Complete: Avg. Loss: 0.0761
# [75/200][3161/3162] Generator_L1_Loss: 0.0764
#  ===> Epoch 75 Complete: Avg. Loss: 0.0761
# [76/200][3161/3162] Generator_L1_Loss: 0.0757
#  ===> Epoch 76 Complete: Avg. Loss: 0.0761
# [77/200][3161/3162] Generator_L1_Loss: 0.0717
#  ===> Epoch 77 Complete: Avg. Loss: 0.0761
# [78/200][3161/3162] Generator_L1_Loss: 0.0792
#  ===> Epoch 78 Complete: Avg. Loss: 0.0761
# [79/200][3161/3162] Generator_L1_Loss: 0.0768
#  ===> Epoch 79 Complete: Avg. Loss: 0.0761
# [80/200][3161/3162] Generator_L1_Loss: 0.0723
#  ===> Epoch 80 Complete: Avg. Loss: 0.0761
# >>>> [80/200] test_loss: 0.07595738815673533
# [81/200][3161/3162] Generator_L1_Loss: 0.0743
#  ===> Epoch 81 Complete: Avg. Loss: 0.0760
# [82/200][3161/3162] Generator_L1_Loss: 0.0716
#  ===> Epoch 82 Complete: Avg. Loss: 0.0760
# [83/200][3161/3162] Generator_L1_Loss: 0.0762
#  ===> Epoch 83 Complete: Avg. Loss: 0.0760
# [84/200][3161/3162] Generator_L1_Loss: 0.0775
#  ===> Epoch 84 Complete: Avg. Loss: 0.0760
# [85/200][3161/3162] Generator_L1_Loss: 0.0688
#  ===> Epoch 85 Complete: Avg. Loss: 0.0760
# [86/200][3161/3162] Generator_L1_Loss: 0.0743
#  ===> Epoch 86 Complete: Avg. Loss: 0.0760
# [87/200][3161/3162] Generator_L1_Loss: 0.0704
#  ===> Epoch 87 Complete: Avg. Loss: 0.0760
# [88/200][3161/3162] Generator_L1_Loss: 0.0744
#  ===> Epoch 88 Complete: Avg. Loss: 0.0760
# [89/200][3161/3162] Generator_L1_Loss: 0.0780
#  ===> Epoch 89 Complete: Avg. Loss: 0.0760
# [90/200][3161/3162] Generator_L1_Loss: 0.0691
#  ===> Epoch 90 Complete: Avg. Loss: 0.0760
# >>>> [90/200] test_loss: 0.07585970197442811
# [91/200][3161/3162] Generator_L1_Loss: 0.0769
#  ===> Epoch 91 Complete: Avg. Loss: 0.0759
# [92/200][3161/3162] Generator_L1_Loss: 0.0760
#  ===> Epoch 92 Complete: Avg. Loss: 0.0759
# [93/200][3161/3162] Generator_L1_Loss: 0.0671
#  ===> Epoch 93 Complete: Avg. Loss: 0.0759
# [94/200][3161/3162] Generator_L1_Loss: 0.0691
#  ===> Epoch 94 Complete: Avg. Loss: 0.0759
# [95/200][3161/3162] Generator_L1_Loss: 0.0724
#  ===> Epoch 95 Complete: Avg. Loss: 0.0759
# [96/200][3161/3162] Generator_L1_Loss: 0.0721
#  ===> Epoch 96 Complete: Avg. Loss: 0.0759
# [97/200][3161/3162] Generator_L1_Loss: 0.0772
#  ===> Epoch 97 Complete: Avg. Loss: 0.0759
# [98/200][3161/3162] Generator_L1_Loss: 0.0747
#  ===> Epoch 98 Complete: Avg. Loss: 0.0759
# [99/200][3161/3162] Generator_L1_Loss: 0.0812
#  ===> Epoch 99 Complete: Avg. Loss: 0.0759
# [100/200][3161/3162] Generator_L1_Loss: 0.0839
#  ===> Epoch 100 Complete: Avg. Loss: 0.0759
# >>>> [100/200] test_loss: 0.0757585616615117
# [101/200][3161/3162] Generator_L1_Loss: 0.0746
#  ===> Epoch 101 Complete: Avg. Loss: 0.0759
# [102/200][3161/3162] Generator_L1_Loss: 0.0679
#  ===> Epoch 102 Complete: Avg. Loss: 0.0758
# [103/200][3161/3162] Generator_L1_Loss: 0.0780
#  ===> Epoch 103 Complete: Avg. Loss: 0.0758
# [104/200][3161/3162] Generator_L1_Loss: 0.0791
#  ===> Epoch 104 Complete: Avg. Loss: 0.0758
# [105/200][3161/3162] Generator_L1_Loss: 0.0837
#  ===> Epoch 105 Complete: Avg. Loss: 0.0758
# [106/200][3161/3162] Generator_L1_Loss: 0.0702
#  ===> Epoch 106 Complete: Avg. Loss: 0.0758
# [107/200][3161/3162] Generator_L1_Loss: 0.0764
#  ===> Epoch 107 Complete: Avg. Loss: 0.0758
# [108/200][3161/3162] Generator_L1_Loss: 0.0823
#  ===> Epoch 108 Complete: Avg. Loss: 0.0758
# [109/200][3161/3162] Generator_L1_Loss: 0.0716
#  ===> Epoch 109 Complete: Avg. Loss: 0.0758
# [110/200][3161/3162] Generator_L1_Loss: 0.0731
#  ===> Epoch 110 Complete: Avg. Loss: 0.0758
# >>>> [110/200] test_loss: 0.07568581647200771
# [111/200][3161/3162] Generator_L1_Loss: 0.0824
#  ===> Epoch 111 Complete: Avg. Loss: 0.0758
# [112/200][3161/3162] Generator_L1_Loss: 0.0761
#  ===> Epoch 112 Complete: Avg. Loss: 0.0758
# [113/200][3161/3162] Generator_L1_Loss: 0.0708
#  ===> Epoch 113 Complete: Avg. Loss: 0.0758
# [114/200][3161/3162] Generator_L1_Loss: 0.0719
#  ===> Epoch 114 Complete: Avg. Loss: 0.0758
# [115/200][3161/3162] Generator_L1_Loss: 0.0827
#  ===> Epoch 115 Complete: Avg. Loss: 0.0757
# [116/200][3161/3162] Generator_L1_Loss: 0.0818
#  ===> Epoch 116 Complete: Avg. Loss: 0.0757
# [117/200][3161/3162] Generator_L1_Loss: 0.0696
#  ===> Epoch 117 Complete: Avg. Loss: 0.0757
# [118/200][3161/3162] Generator_L1_Loss: 0.0728
#  ===> Epoch 118 Complete: Avg. Loss: 0.0757
# [119/200][3161/3162] Generator_L1_Loss: 0.0707
#  ===> Epoch 119 Complete: Avg. Loss: 0.0757
# [120/200][3161/3162] Generator_L1_Loss: 0.0723
#  ===> Epoch 120 Complete: Avg. Loss: 0.0757
# >>>> [120/200] test_loss: 0.07562390951305514
# [121/200][3161/3162] Generator_L1_Loss: 0.0712
#  ===> Epoch 121 Complete: Avg. Loss: 0.0757
# [122/200][3161/3162] Generator_L1_Loss: 0.0755
#  ===> Epoch 122 Complete: Avg. Loss: 0.0757
# [123/200][3161/3162] Generator_L1_Loss: 0.0751
#  ===> Epoch 123 Complete: Avg. Loss: 0.0757
# [124/200][3161/3162] Generator_L1_Loss: 0.0669
#  ===> Epoch 124 Complete: Avg. Loss: 0.0757
# [125/200][3161/3162] Generator_L1_Loss: 0.0823
#  ===> Epoch 125 Complete: Avg. Loss: 0.0757
# [126/200][3161/3162] Generator_L1_Loss: 0.0840
#  ===> Epoch 126 Complete: Avg. Loss: 0.0757
# [127/200][3161/3162] Generator_L1_Loss: 0.0721
#  ===> Epoch 127 Complete: Avg. Loss: 0.0757
# [128/200][3161/3162] Generator_L1_Loss: 0.0805
#  ===> Epoch 128 Complete: Avg. Loss: 0.0757
# [129/200][3161/3162] Generator_L1_Loss: 0.0717
#  ===> Epoch 129 Complete: Avg. Loss: 0.0757
# [130/200][3161/3162] Generator_L1_Loss: 0.0802
#  ===> Epoch 130 Complete: Avg. Loss: 0.0757
# >>>> [130/200] test_loss: 0.07555867414144439
# [131/200][3161/3162] Generator_L1_Loss: 0.0785
#  ===> Epoch 131 Complete: Avg. Loss: 0.0756
# [132/200][3161/3162] Generator_L1_Loss: 0.0795
#  ===> Epoch 132 Complete: Avg. Loss: 0.0756
# [133/200][3161/3162] Generator_L1_Loss: 0.0765
#  ===> Epoch 133 Complete: Avg. Loss: 0.0756
# [134/200][3161/3162] Generator_L1_Loss: 0.0774
#  ===> Epoch 134 Complete: Avg. Loss: 0.0756
# [135/200][3161/3162] Generator_L1_Loss: 0.0669
#  ===> Epoch 135 Complete: Avg. Loss: 0.0756
# [136/200][3161/3162] Generator_L1_Loss: 0.0760
#  ===> Epoch 136 Complete: Avg. Loss: 0.0756
# [137/200][3161/3162] Generator_L1_Loss: 0.0759
#  ===> Epoch 137 Complete: Avg. Loss: 0.0756
# [138/200][3161/3162] Generator_L1_Loss: 0.0841
#  ===> Epoch 138 Complete: Avg. Loss: 0.0756
# [139/200][3161/3162] Generator_L1_Loss: 0.0741
#  ===> Epoch 139 Complete: Avg. Loss: 0.0756
# [140/200][3161/3162] Generator_L1_Loss: 0.0742
#  ===> Epoch 140 Complete: Avg. Loss: 0.0756
# >>>> [140/200] test_loss: 0.07551311832462942
# [141/200][3161/3162] Generator_L1_Loss: 0.0830
#  ===> Epoch 141 Complete: Avg. Loss: 0.0756
# [142/200][3161/3162] Generator_L1_Loss: 0.0744
#  ===> Epoch 142 Complete: Avg. Loss: 0.0756
# [143/200][3161/3162] Generator_L1_Loss: 0.0729
#  ===> Epoch 143 Complete: Avg. Loss: 0.0756
# [144/200][3161/3162] Generator_L1_Loss: 0.0696
#  ===> Epoch 144 Complete: Avg. Loss: 0.0756
# [145/200][3161/3162] Generator_L1_Loss: 0.0789
#  ===> Epoch 145 Complete: Avg. Loss: 0.0756
# [146/200][3161/3162] Generator_L1_Loss: 0.0726
#  ===> Epoch 146 Complete: Avg. Loss: 0.0756
# [147/200][3161/3162] Generator_L1_Loss: 0.0726
#  ===> Epoch 147 Complete: Avg. Loss: 0.0756
# [148/200][3161/3162] Generator_L1_Loss: 0.0716
#  ===> Epoch 148 Complete: Avg. Loss: 0.0756
# [149/200][3161/3162] Generator_L1_Loss: 0.0697
#  ===> Epoch 149 Complete: Avg. Loss: 0.0756
# [150/200][3161/3162] Generator_L1_Loss: 0.0772
#  ===> Epoch 150 Complete: Avg. Loss: 0.0756
# >>>> [150/200] test_loss: 0.07546547088211616
# [151/200][3161/3162] Generator_L1_Loss: 0.0837
#  ===> Epoch 151 Complete: Avg. Loss: 0.0756
# [152/200][3161/3162] Generator_L1_Loss: 0.0806
#  ===> Epoch 152 Complete: Avg. Loss: 0.0755
# [153/200][3161/3162] Generator_L1_Loss: 0.0694
#  ===> Epoch 153 Complete: Avg. Loss: 0.0755
# [154/200][3161/3162] Generator_L1_Loss: 0.0732
#  ===> Epoch 154 Complete: Avg. Loss: 0.0755
# [155/200][3161/3162] Generator_L1_Loss: 0.0721
#  ===> Epoch 155 Complete: Avg. Loss: 0.0755
# [156/200][3161/3162] Generator_L1_Loss: 0.0748
#  ===> Epoch 156 Complete: Avg. Loss: 0.0755
# [157/200][3161/3162] Generator_L1_Loss: 0.0686
#  ===> Epoch 157 Complete: Avg. Loss: 0.0755
# [158/200][3161/3162] Generator_L1_Loss: 0.0794
#  ===> Epoch 158 Complete: Avg. Loss: 0.0755
# [159/200][3161/3162] Generator_L1_Loss: 0.0752
#  ===> Epoch 159 Complete: Avg. Loss: 0.0755
# [160/200][3161/3162] Generator_L1_Loss: 0.0775
#  ===> Epoch 160 Complete: Avg. Loss: 0.0755
# >>>> [160/200] test_loss: 0.07542723206292211
# [161/200][3161/3162] Generator_L1_Loss: 0.0744
#  ===> Epoch 161 Complete: Avg. Loss: 0.0755
# [162/200][3161/3162] Generator_L1_Loss: 0.0710
#  ===> Epoch 162 Complete: Avg. Loss: 0.0755
# [163/200][3161/3162] Generator_L1_Loss: 0.0775
#  ===> Epoch 163 Complete: Avg. Loss: 0.0755
# [164/200][3161/3162] Generator_L1_Loss: 0.0764
#  ===> Epoch 164 Complete: Avg. Loss: 0.0755
# [165/200][3161/3162] Generator_L1_Loss: 0.0779
#  ===> Epoch 165 Complete: Avg. Loss: 0.0755
# [166/200][3161/3162] Generator_L1_Loss: 0.0773
#  ===> Epoch 166 Complete: Avg. Loss: 0.0755
# [167/200][3161/3162] Generator_L1_Loss: 0.0732
#  ===> Epoch 167 Complete: Avg. Loss: 0.0755
# [168/200][3161/3162] Generator_L1_Loss: 0.0749
#  ===> Epoch 168 Complete: Avg. Loss: 0.0755
# [169/200][3161/3162] Generator_L1_Loss: 0.0687
#  ===> Epoch 169 Complete: Avg. Loss: 0.0755
# [170/200][3161/3162] Generator_L1_Loss: 0.0729
#  ===> Epoch 170 Complete: Avg. Loss: 0.0755
# >>>> [170/200] test_loss: 0.07540810949318628
# [171/200][3161/3162] Generator_L1_Loss: 0.0720
#  ===> Epoch 171 Complete: Avg. Loss: 0.0755
# [172/200][3161/3162] Generator_L1_Loss: 0.0783
#  ===> Epoch 172 Complete: Avg. Loss: 0.0755
# [173/200][3161/3162] Generator_L1_Loss: 0.0777
#  ===> Epoch 173 Complete: Avg. Loss: 0.0755
# [174/200][3161/3162] Generator_L1_Loss: 0.0802
#  ===> Epoch 174 Complete: Avg. Loss: 0.0755
# [175/200][3161/3162] Generator_L1_Loss: 0.0789
#  ===> Epoch 175 Complete: Avg. Loss: 0.0755
# [176/200][3161/3162] Generator_L1_Loss: 0.0705
#  ===> Epoch 176 Complete: Avg. Loss: 0.0755
# [177/200][3161/3162] Generator_L1_Loss: 0.0749
#  ===> Epoch 177 Complete: Avg. Loss: 0.0755
# [178/200][3161/3162] Generator_L1_Loss: 0.0792
#  ===> Epoch 178 Complete: Avg. Loss: 0.0755
# [179/200][3161/3162] Generator_L1_Loss: 0.0785
#  ===> Epoch 179 Complete: Avg. Loss: 0.0755
# [180/200][3161/3162] Generator_L1_Loss: 0.0774
#  ===> Epoch 180 Complete: Avg. Loss: 0.0755
# >>>> [180/200] test_loss: 0.07538072915580571
# [181/200][3161/3162] Generator_L1_Loss: 0.0691
#  ===> Epoch 181 Complete: Avg. Loss: 0.0755
# [182/200][3161/3162] Generator_L1_Loss: 0.0805
#  ===> Epoch 182 Complete: Avg. Loss: 0.0755
# [183/200][3161/3162] Generator_L1_Loss: 0.0754
#  ===> Epoch 183 Complete: Avg. Loss: 0.0755
# [184/200][3161/3162] Generator_L1_Loss: 0.0769
#  ===> Epoch 184 Complete: Avg. Loss: 0.0755
# [185/200][3161/3162] Generator_L1_Loss: 0.0756
#  ===> Epoch 185 Complete: Avg. Loss: 0.0755
# [186/200][3161/3162] Generator_L1_Loss: 0.0757
#  ===> Epoch 186 Complete: Avg. Loss: 0.0755
# [187/200][3161/3162] Generator_L1_Loss: 0.0766
#  ===> Epoch 187 Complete: Avg. Loss: 0.0755
# [188/200][3161/3162] Generator_L1_Loss: 0.0776
#  ===> Epoch 188 Complete: Avg. Loss: 0.0755
# [189/200][3161/3162] Generator_L1_Loss: 0.0734
#  ===> Epoch 189 Complete: Avg. Loss: 0.0755
# [190/200][3161/3162] Generator_L1_Loss: 0.0756
#  ===> Epoch 190 Complete: Avg. Loss: 0.0755
# >>>> [190/200] test_loss: 0.07536967984116937
# [191/200][3161/3162] Generator_L1_Loss: 0.0811
#  ===> Epoch 191 Complete: Avg. Loss: 0.0754
# [192/200][3161/3162] Generator_L1_Loss: 0.0738
#  ===> Epoch 192 Complete: Avg. Loss: 0.0755
# [193/200][3161/3162] Generator_L1_Loss: 0.0760
#  ===> Epoch 193 Complete: Avg. Loss: 0.0754
# [194/200][1757/3162] Generator_L1_Loss: 0.0773

# %%
valid_dataset = data_loader(args, 'valid')
test_loss = test(args, generator, p, valid_dataset, criterion=criterionMSE)

# %%
test_loss
# Out:
# 0.004491226463970535

# %%
t = 50
l = args.percep_weight
p = args.dropout_rate 
print_output(generator, p, t, valid_dataset)
# Out:
# ===> 8x:

# %%
t = 100
l = args.percep_weight
p = args.dropout_rate 
print_output(generator, p, t, train_dataset)
# Out:
# ===> 8x:
