# %%
###################################################################################################
##### super resolution of whole slide images with conditional generative adversarial networks #####
###################################################################################################
#### SCL+GAN
import os, shutil, glob, warnings
import argparse
import sys
from datetime import datetime

import matplotlib.pyplot as plt
from torchvision import transforms, utils
import torchvision
from skimage import exposure, color, io, img_as_float, img_as_ubyte
from skimage.util import view_as_windows, pad, montage
# from scipy.stats import signaltonoise
from PIL import Image, ImageFilter

from math import log10, log, exp, e, log2
import pandas as pd
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from collections import OrderedDict

import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.optim.lr_scheduler as lr_scheduler

import data
import srmodels as models

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# %%
def data_loader(args, csv='train'):
    if csv=='train':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv),
                                                   transform=data.Compose([
#                                                        data.RandomCrop((args.patch_size, args.patch_size)),
                                                       data.Recale(args.patch_size),
#                                                        data.Flip(),
#                                                        data.Rotate(),
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers)
    if csv=='valid':
        transformed_dataset = data.Pair_Dataset(csv_file=data.compress_csv_path(csv),
                                                   transform=data.Compose([
#                                                        data.Crop((args.patch_size, args.patch_size)),
                                                       data.Recale(args.patch_size),
                                                       data.ToTensor()
                                               ]))
        dataloader = DataLoader(transformed_dataset, batch_size=args.batch_size, shuffle=False, num_workers=args.num_workers)
    return dataloader

# %%
def train(args, epoch, run, l, dataloader, gan=True):
    epoch_loss = 0
    gan_loss = 0
    total_loss = 0
    dis_loss = 0
    generator.train()
    for iteration, batch in enumerate(dataloader):
        real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
        real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
        
        # Adversarial ground truths
        valid = Variable(Tensor(np.ones((real_mid.size(0), *patch))).to(device), requires_grad=False)
        fake = Variable(Tensor(np.zeros((real_mid.size(0), *patch))).to(device), requires_grad=False)
        
        #---------------
        #  Train Generator
        #---------------   
        
        optimizer_G.zero_grad()
        
        # GAN loss
        fake_high = generator(real_mid)
        if gan:
            pred_fake = discriminator(fake_high, real_mid)
            loss_GAN = criterionMSE(pred_fake, valid)
        
        # Identity
        lossL1 = criterionL(fake_high, real_high)               
        loss_pixel = lossL1
        
        # Total loss
        if gan:
            loss_G = l * loss_GAN + (1-l) * loss_pixel   
            loss_G.backward()
            total_loss = total_loss + loss_G.item()
            gan_loss = gan_loss + loss_GAN.item()
        else:
            loss_pixel.backward()
        optimizer_G.step()
        
        #---------------
        #  Train Discriminator
        #---------------  
        
        if gan and iteration % args.num_critic == 0:
            optimizer_D.zero_grad() 
            # Real loss
            pred_real = discriminator(real_high, real_mid)
            loss_real = criterionMSE(pred_real, valid)
        
            # Fake loss
            pred_fake = discriminator(fake_high.detach(), real_mid)
            loss_fake = criterionMSE(pred_fake, fake)

            # Total loss
            loss_D = 0.5 * (loss_real + loss_fake)
            loss_D.backward()
            optimizer_D.step()
            dis_loss = dis_loss + loss_D.item()
        
        epoch_loss = epoch_loss + loss_pixel.item()
        
        if gan:
            sys.stdout.write('\r[%d/%d][%d/%d] Discriminator_Loss: %.4f Generator_Loss (Identity/Advers/Total): %.4f/%.4f/%.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_D.item(), 
                                loss_pixel.item(), loss_GAN.item(), loss_G.item()))
        else:
            sys.stdout.write('\r[%d/%d][%d/%d] Generator_L1_Loss: %.4f' 
                             % (epoch, args.num_epochs, iteration, len(dataloader), loss_pixel.item()))
    print("\n ===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(dataloader)))
    
    g_path = os.path.join('weights', run, 'generator.pth')
    d_path = os.path.join('weights', run, 'discriminator.pth')
    os.makedirs(os.path.join('weights', run), exist_ok=True)
    torch.save(generator.state_dict(), g_path)
    if gan:
        os.makedirs(os.path.join('weights', run), exist_ok=True)
        torch.save(discriminator.state_dict(), d_path)

# %%
def print_output(trained_model, dataloader_valid):
    generator.eval()
    os.makedirs('print-sr', exist_ok=True)
    with torch.no_grad():      
        print("===> 8x:")
        for iteration, batch in enumerate(dataloader_valid):     
            input, target = batch['input'].to(device), batch['output'].to(device)
            imgs_input = Variable(input.type(Tensor))
            prediction = trained_model(imgs_input)
            target = target.float()    
            imgs_input = imgs_input[:, :, :, :]
            prediction = prediction[:, :, :, :]
            target = target[:, :, :, :]
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(imgs_input).cpu()
            utils.save_image(grid, 'print-sr/input.tif')
            input_downsampled = grid.numpy().transpose((1, 2, 0))
            plt.imshow(input_downsampled, interpolation='bicubic')
            plt.axis('off') 
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(prediction).cpu()
            utils.save_image(grid, 'print-sr/output.tif')
            prediction = np.clip(grid.numpy().transpose((1, 2, 0)), 0, 1)
            plt.imshow(prediction, interpolation='bicubic')
            plt.axis('off')    
            plt.figure(figsize=(20, 6))
            grid = utils.make_grid(target).cpu()
            utils.save_image(grid, 'print-sr/target.tif')
            target = grid.numpy().transpose((1, 2, 0))
            plt.imshow(target, interpolation='bicubic')
            plt.axis('off')                                  
            break

# %%
def p_snr(path_input, path_ref):
    MSE = nn.MSELoss()
    imgs_input = glob.glob(os.path.join(path_input, '*.tiff'))
    imgs_ref = glob.glob(os.path.join(path_ref, '*.tiff'))
    ave_psnr = 0
    for i in range(len(imgs_input)):
        img_input = torch.from_numpy(img_as_float(io.imread(imgs_input[i]).transpose(2, 1, 0)))               
        img_ref = torch.from_numpy(img_as_float(io.imread(imgs_ref[i]).transpose(2, 1, 0)))
        img_input = img_input[None, :]
        img_ref = img_ref[None, :]             
        mse = MSE(img_input, img_ref)               
        psnr = 10 * log10(1 / mse.item())
        ave_psnr += psnr
    ave_psnr = ave_psnr / len(imgs_input)
    return ave_psnr

# %%
def test(args, generator, dataloader, criterion):
    with torch.no_grad():
        epoch_loss = 0
        generator.eval()
        for iteration, batch in enumerate(dataloader):
            real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
            real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
            fake_high = generator(real_mid)
            epoch_loss = epoch_loss + criterion(fake_high, real_high).item()
        return epoch_loss / len(dataloader)

# %%
args = argparse.Namespace()
args.img_channel = 1
args.batch_size = 16
args.patch_size = 512
args.up_scale = 5
args.num_workers = 0
args.num_epochs = 100
args.g_lr = 0.0001
args.d_lr = 0.00001
args.dataset = 'TMA'
args.num_critic = 10
args.normalize = None
args.percep_weight = 0.03
args.run_from = None
args.start_epoch = 1
args.gan = True

# %%
device = torch.device('cuda:0')
data.generate_compress_csv()
valid_dataset = data_loader(args, 'valid')
data.show_patch(valid_dataset, 0)
# define model
generator = models.Generator(args.img_channel, base_channel=16, norm='instance')
# generator = models.Net(args.img_channel, upscale_factor=2)
generator.to(device);
discriminator = models.Discriminator(args.img_channel, norm='batch')
discriminator.to(device);
criterionL = nn.L1Loss().cuda()
criterionMSE = nn.MSELoss().cuda()
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
patch = (1, args.patch_size // 2 ** 4, args.patch_size // 2 ** 4)
Tensor = torch.cuda.FloatTensor

# %%
if args.run_from is not None:
    generator.load_state_dict(torch.load(os.path.join('weights', args.run_from, 'generator.pth')))
    try:
        discriminator.load_state_dict(torch.load(os.path.join('weights', args.run_from, 'discriminator.pth')))
    except:
        print('Discriminator weights not found!')
        pass

# %%
optimizer_G = torch.optim.Adam(generator.parameters(), lr=args.g_lr)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=args.d_lr)
scheduler_G = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_G, args.num_epochs, args.g_lr*0.05)
scheduler_D = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_D, args.num_epochs, args.d_lr*0.05)

# %%
warnings.filterwarnings('ignore')

# %%
run = datetime.now().strftime("%Y-%m-%d--%H-%M-%S")
train_dataset = data_loader(args, 'train')
l = args.percep_weight
for epoch in range(35, args.num_epochs):
    gan = True
    train(args, epoch, run, l, train_dataset, gan)   
    scheduler_G.step()
    scheduler_D.step()
    if epoch % 10 == 0:
        test_loss = test(args, generator, valid_dataset, criterion=criterionMSE)
        print('\r>>>> [{}/{}] test_loss: {}'.format(epoch, args.num_epochs, test_loss))
# Out:
# [35/100][1420/1421] Discriminator_Loss: 0.2016 Generator_Loss (Identity/Advers/Total): 0.0966/0.2792/0.1020
#  ===> Epoch 35 Complete: Avg. Loss: 0.0940
# [36/100][1420/1421] Discriminator_Loss: 0.1927 Generator_Loss (Identity/Advers/Total): 0.1099/0.3923/0.1183
#  ===> Epoch 36 Complete: Avg. Loss: 0.0940
# [37/100][1420/1421] Discriminator_Loss: 0.2304 Generator_Loss (Identity/Advers/Total): 0.0817/0.6195/0.0978
#  ===> Epoch 37 Complete: Avg. Loss: 0.0940
# [38/100][1420/1421] Discriminator_Loss: 0.2167 Generator_Loss (Identity/Advers/Total): 0.0923/0.1784/0.0949
#  ===> Epoch 38 Complete: Avg. Loss: 0.0939
# [39/100][1420/1421] Discriminator_Loss: 0.2892 Generator_Loss (Identity/Advers/Total): 0.0887/0.0939/0.0888
#  ===> Epoch 39 Complete: Avg. Loss: 0.0941
# [40/100][1420/1421] Discriminator_Loss: 0.2537 Generator_Loss (Identity/Advers/Total): 0.0905/0.2067/0.0940
#  ===> Epoch 40 Complete: Avg. Loss: 0.0941
# >>>> [40/100] test_loss: 0.01802131634603223
# [41/100][1420/1421] Discriminator_Loss: 0.2227 Generator_Loss (Identity/Advers/Total): 0.0870/0.1934/0.0902
#  ===> Epoch 41 Complete: Avg. Loss: 0.0942
# [42/100][1420/1421] Discriminator_Loss: 0.2296 Generator_Loss (Identity/Advers/Total): 0.0974/0.2083/0.1007
#  ===> Epoch 42 Complete: Avg. Loss: 0.0943
# [43/100][1420/1421] Discriminator_Loss: 0.2894 Generator_Loss (Identity/Advers/Total): 0.0979/0.4131/0.1074
#  ===> Epoch 43 Complete: Avg. Loss: 0.0940
# [44/100][1420/1421] Discriminator_Loss: 0.2327 Generator_Loss (Identity/Advers/Total): 0.0889/0.3567/0.0970
#  ===> Epoch 44 Complete: Avg. Loss: 0.0942
# [45/100][1420/1421] Discriminator_Loss: 0.2364 Generator_Loss (Identity/Advers/Total): 0.0901/0.4631/0.1013
#  ===> Epoch 45 Complete: Avg. Loss: 0.0941
# [46/100][1420/1421] Discriminator_Loss: 0.2185 Generator_Loss (Identity/Advers/Total): 0.1009/0.3064/0.1070
#  ===> Epoch 46 Complete: Avg. Loss: 0.0942
# [47/100][1420/1421] Discriminator_Loss: 0.2518 Generator_Loss (Identity/Advers/Total): 0.1012/0.2907/0.1069
#  ===> Epoch 47 Complete: Avg. Loss: 0.0944
# [48/100][1420/1421] Discriminator_Loss: 0.2209 Generator_Loss (Identity/Advers/Total): 0.0908/0.2238/0.0948
#  ===> Epoch 48 Complete: Avg. Loss: 0.0942
# [49/100][1420/1421] Discriminator_Loss: 0.2334 Generator_Loss (Identity/Advers/Total): 0.0919/0.3078/0.0984
#  ===> Epoch 49 Complete: Avg. Loss: 0.0945
# [50/100][1420/1421] Discriminator_Loss: 0.1927 Generator_Loss (Identity/Advers/Total): 0.0955/0.2937/0.1014
#  ===> Epoch 50 Complete: Avg. Loss: 0.0944
# >>>> [50/100] test_loss: 0.017005672489994027
# [51/100][1420/1421] Discriminator_Loss: 0.2137 Generator_Loss (Identity/Advers/Total): 0.0936/0.3305/0.1007
#  ===> Epoch 51 Complete: Avg. Loss: 0.0947
# [52/100][1420/1421] Discriminator_Loss: 0.2106 Generator_Loss (Identity/Advers/Total): 0.1038/0.2735/0.1089
#  ===> Epoch 52 Complete: Avg. Loss: 0.0947
# [53/100][1420/1421] Discriminator_Loss: 0.2037 Generator_Loss (Identity/Advers/Total): 0.0905/0.4321/0.1008
#  ===> Epoch 53 Complete: Avg. Loss: 0.0945
# [54/100][1420/1421] Discriminator_Loss: 0.2146 Generator_Loss (Identity/Advers/Total): 0.0927/0.2344/0.0970
#  ===> Epoch 54 Complete: Avg. Loss: 0.0944
# [55/100][1420/1421] Discriminator_Loss: 0.2045 Generator_Loss (Identity/Advers/Total): 0.0860/0.2374/0.0905
#  ===> Epoch 55 Complete: Avg. Loss: 0.0946
# [56/100][1420/1421] Discriminator_Loss: 0.2265 Generator_Loss (Identity/Advers/Total): 0.0972/0.2081/0.1005
#  ===> Epoch 56 Complete: Avg. Loss: 0.0945
# [57/100][1420/1421] Discriminator_Loss: 0.2159 Generator_Loss (Identity/Advers/Total): 0.1096/0.3549/0.1169
#  ===> Epoch 57 Complete: Avg. Loss: 0.0945
# [58/100][1420/1421] Discriminator_Loss: 0.2438 Generator_Loss (Identity/Advers/Total): 0.0962/0.2055/0.0994
#  ===> Epoch 58 Complete: Avg. Loss: 0.0946
# [59/100][1420/1421] Discriminator_Loss: 0.2851 Generator_Loss (Identity/Advers/Total): 0.0925/0.4302/0.1026
#  ===> Epoch 59 Complete: Avg. Loss: 0.0946
# [60/100][1420/1421] Discriminator_Loss: 0.2248 Generator_Loss (Identity/Advers/Total): 0.0917/0.3662/0.0999
#  ===> Epoch 60 Complete: Avg. Loss: 0.0945
# >>>> [60/100] test_loss: 0.018260124197041386
# [61/100][1420/1421] Discriminator_Loss: 0.2084 Generator_Loss (Identity/Advers/Total): 0.0998/0.2977/0.1058
#  ===> Epoch 61 Complete: Avg. Loss: 0.0945
# [62/100][1420/1421] Discriminator_Loss: 0.2343 Generator_Loss (Identity/Advers/Total): 0.0897/0.2520/0.0946
#  ===> Epoch 62 Complete: Avg. Loss: 0.0945
# [63/100][1420/1421] Discriminator_Loss: 0.1871 Generator_Loss (Identity/Advers/Total): 0.0979/0.4194/0.1076
#  ===> Epoch 63 Complete: Avg. Loss: 0.0943
# [64/100][1420/1421] Discriminator_Loss: 0.2135 Generator_Loss (Identity/Advers/Total): 0.0927/0.3668/0.1009
#  ===> Epoch 64 Complete: Avg. Loss: 0.0944
# [65/100][1420/1421] Discriminator_Loss: 0.2409 Generator_Loss (Identity/Advers/Total): 0.0966/0.3864/0.1052
#  ===> Epoch 65 Complete: Avg. Loss: 0.0945
# [66/100][1420/1421] Discriminator_Loss: 0.2098 Generator_Loss (Identity/Advers/Total): 0.0923/0.4157/0.1021
#  ===> Epoch 66 Complete: Avg. Loss: 0.0945
# [67/100][1420/1421] Discriminator_Loss: 0.2143 Generator_Loss (Identity/Advers/Total): 0.0885/0.2356/0.0929
#  ===> Epoch 67 Complete: Avg. Loss: 0.0944
# [68/100][1420/1421] Discriminator_Loss: 0.1504 Generator_Loss (Identity/Advers/Total): 0.0925/0.2881/0.0983
#  ===> Epoch 68 Complete: Avg. Loss: 0.0944
# [69/100][1420/1421] Discriminator_Loss: 0.2103 Generator_Loss (Identity/Advers/Total): 0.0911/0.3511/0.0989
#  ===> Epoch 69 Complete: Avg. Loss: 0.0946
# [70/100][1420/1421] Discriminator_Loss: 0.2132 Generator_Loss (Identity/Advers/Total): 0.0877/0.2250/0.0918
#  ===> Epoch 70 Complete: Avg. Loss: 0.0949
# >>>> [70/100] test_loss: 0.017538508342767364
# [71/100][1420/1421] Discriminator_Loss: 0.1656 Generator_Loss (Identity/Advers/Total): 0.0985/0.2806/0.1039
#  ===> Epoch 71 Complete: Avg. Loss: 0.0949
# [72/100][1420/1421] Discriminator_Loss: 0.2074 Generator_Loss (Identity/Advers/Total): 0.0968/0.3353/0.1039
#  ===> Epoch 72 Complete: Avg. Loss: 0.0948
# [73/100][1420/1421] Discriminator_Loss: 0.2432 Generator_Loss (Identity/Advers/Total): 0.0863/0.4861/0.0983
#  ===> Epoch 73 Complete: Avg. Loss: 0.0945
# [74/100][1420/1421] Discriminator_Loss: 0.2030 Generator_Loss (Identity/Advers/Total): 0.0890/0.3048/0.0955
#  ===> Epoch 74 Complete: Avg. Loss: 0.0944
# [75/100][1420/1421] Discriminator_Loss: 0.2240 Generator_Loss (Identity/Advers/Total): 0.0901/0.1712/0.0925
#  ===> Epoch 75 Complete: Avg. Loss: 0.0947
# [76/100][1420/1421] Discriminator_Loss: 0.2424 Generator_Loss (Identity/Advers/Total): 0.1049/0.3231/0.1115
#  ===> Epoch 76 Complete: Avg. Loss: 0.0950
# [77/100][1420/1421] Discriminator_Loss: 0.1991 Generator_Loss (Identity/Advers/Total): 0.0923/0.3425/0.0998
#  ===> Epoch 77 Complete: Avg. Loss: 0.0948
# [78/100][1420/1421] Discriminator_Loss: 0.2340 Generator_Loss (Identity/Advers/Total): 0.0891/0.2166/0.0929
#  ===> Epoch 78 Complete: Avg. Loss: 0.0948
# [79/100][1420/1421] Discriminator_Loss: 0.1481 Generator_Loss (Identity/Advers/Total): 0.0924/0.3824/0.1011
#  ===> Epoch 79 Complete: Avg. Loss: 0.0946
# [80/100][1420/1421] Discriminator_Loss: 0.2581 Generator_Loss (Identity/Advers/Total): 0.0966/0.3010/0.1027
#  ===> Epoch 80 Complete: Avg. Loss: 0.0947
# >>>> [80/100] test_loss: 0.018047084744098815
# [81/100][1420/1421] Discriminator_Loss: 0.1840 Generator_Loss (Identity/Advers/Total): 0.0826/0.4378/0.0932
#  ===> Epoch 81 Complete: Avg. Loss: 0.0943
# [82/100][1420/1421] Discriminator_Loss: 0.2611 Generator_Loss (Identity/Advers/Total): 0.1003/0.2425/0.1045
#  ===> Epoch 82 Complete: Avg. Loss: 0.0943
# [83/100][1420/1421] Discriminator_Loss: 0.2403 Generator_Loss (Identity/Advers/Total): 0.0958/0.2300/0.0998
#  ===> Epoch 83 Complete: Avg. Loss: 0.0945
# [84/100][1420/1421] Discriminator_Loss: 0.2211 Generator_Loss (Identity/Advers/Total): 0.0906/0.4377/0.1010
#  ===> Epoch 84 Complete: Avg. Loss: 0.0946
# [85/100][1420/1421] Discriminator_Loss: 0.1823 Generator_Loss (Identity/Advers/Total): 0.0867/0.4023/0.0962
#  ===> Epoch 85 Complete: Avg. Loss: 0.0946
# [86/100][1420/1421] Discriminator_Loss: 0.2010 Generator_Loss (Identity/Advers/Total): 0.0906/0.2778/0.0962
#  ===> Epoch 86 Complete: Avg. Loss: 0.0947
# [87/100][1420/1421] Discriminator_Loss: 0.2258 Generator_Loss (Identity/Advers/Total): 0.0877/0.4249/0.0978
#  ===> Epoch 87 Complete: Avg. Loss: 0.0945
# [88/100][1420/1421] Discriminator_Loss: 0.2402 Generator_Loss (Identity/Advers/Total): 0.0884/0.3024/0.0948
#  ===> Epoch 88 Complete: Avg. Loss: 0.0945
# [89/100][1420/1421] Discriminator_Loss: 0.2415 Generator_Loss (Identity/Advers/Total): 0.1021/0.3040/0.1081
#  ===> Epoch 89 Complete: Avg. Loss: 0.0943
# [90/100][1420/1421] Discriminator_Loss: 0.2140 Generator_Loss (Identity/Advers/Total): 0.0957/0.2432/0.1002
#  ===> Epoch 90 Complete: Avg. Loss: 0.0943
# >>>> [90/100] test_loss: 0.017292576698125915
# [91/100][1420/1421] Discriminator_Loss: 0.1228 Generator_Loss (Identity/Advers/Total): 0.0902/0.3355/0.0976
#  ===> Epoch 91 Complete: Avg. Loss: 0.0944
# [92/100][1420/1421] Discriminator_Loss: 0.2427 Generator_Loss (Identity/Advers/Total): 0.0931/0.2426/0.0976
#  ===> Epoch 92 Complete: Avg. Loss: 0.0943
# [93/100][1420/1421] Discriminator_Loss: 0.2323 Generator_Loss (Identity/Advers/Total): 0.0893/0.3225/0.0963
#  ===> Epoch 93 Complete: Avg. Loss: 0.0946
# [94/100][1420/1421] Discriminator_Loss: 0.2200 Generator_Loss (Identity/Advers/Total): 0.0951/0.2906/0.1010
#  ===> Epoch 94 Complete: Avg. Loss: 0.0945
# [95/100][1420/1421] Discriminator_Loss: 0.2219 Generator_Loss (Identity/Advers/Total): 0.0892/0.2409/0.0937
#  ===> Epoch 95 Complete: Avg. Loss: 0.0944
# [96/100][906/1421] Discriminator_Loss: 0.1880 Generator_Loss (Identity/Advers/Total): 0.0869/0.4102/0.0966
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-b5f0be996e80> in <module>
#       4 for epoch in range(35, args.num_epochs):
#       5     gan = True
# ----> 6     train(args, epoch, run, l, train_dataset, gan)
#       7     scheduler_G.step()
#       8     scheduler_D.step()
#
# <ipython-input-4-719931f83e12> in train(args, epoch, run, l, dataloader, gan)
#       5     dis_loss = 0
#       6     generator.train()
# ----> 7     for iteration, batch in enumerate(dataloader):
#       8         real_mid = Variable(batch['input'].type(Tensor).to(device), requires_grad=False)
#       9         real_high = Variable(batch['output'].type(Tensor).to(device), requires_grad=False)
#
# ~/miniconda3/envs/dsmil/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniconda3/envs/dsmil/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/miniconda3/envs/dsmil/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniconda3/envs/dsmil/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /data/binli/Projects/lsm-run-time-enhancement/data.py in __getitem__(self, idx)
#      30         sample = {'input': in_img, 'output': out_img}
#      31         if self.transform:
# ---> 32             sample = self.transform(sample)
#      33         return sample
#      34
#
# /data/binli/Projects/lsm-run-time-enhancement/data.py in __call__(self, img)
#      39     def __call__(self, img):
#      40         for t in self.transforms:
# ---> 41             img = t(img)
#      42         return img
#      43
#
# /data/binli/Projects/lsm-run-time-enhancement/data.py in __call__(self, sample)
#     129     def __call__(self, sample):
#     130         in_img, out_img = sample['input'], sample['output']
# --> 131         return {'input': transforms.functional.to_tensor(np.array(in_img)), 'output': transforms.functional.to_tensor(np.array(out_img))}
#     132
#     133 def show_patch(dataloader, index = 0, img_channel=1):
#
# ~/miniconda3/envs/dsmil/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      75         # backward compatibility
#      76         if isinstance(img, torch.ByteTensor):
# ---> 77             return img.float().div(255)
#      78         else:
#      79             return img
#
# KeyboardInterrupt:

# %%
valid_dataset = data_loader(args, 'valid')
test_loss = test(args, generator, valid_dataset, criterion=criterionMSE)

# %%
test_loss
# Out:
# 0.02450912140987136

# %%
print_output(generator, valid_dataset)
# Out:
# ===> 8x:

# %%
print_output(generator, train_dataset)
# Out:
# ===> 8x:
